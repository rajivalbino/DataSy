# %% [markdown]
# ### Task Metrics for PI10

# %%
import numpy as numpy
import pandas as pd

# %%
# Find encoding
#with open('data/Tasks PI10.csv') as f:
#   print(f)

tasks = pd.read_csv('data/data-transformed.txt')
tasks.head(20)
# Out:
#         Id                                     Summary  \
# 0   392995    [Doc] Authorship - p8445-5 - 2021.48.0.0
# 1   392996  [Doc] First Review - p8445-5 - 2021.48.0.0
# 2   392997      [Doc] Authorship - p9008 - 2021.48.0.0
# 3   392998    [Doc] First Review - p9008 - 2021.48.0.0
# 4   392999    [Doc] Authorship - p9045-1 - 2021.48.0.0
# 5   393000  [Doc] First Review - p9045-1 - 2021.48.0.0
# 6   425773                   Proto code implementation
# 7   429405                              Implementation
# 8   429406                   Implementation 1st Review
# 9   429407                   Implementation 2nd Review
# 10  429414                              Implementation
# 11  429415                   Implementation 1st Review
# 12  429416                   Implementation 2nd review
# 13  429417                              Implementation
# 14  429418                   Implementation 1st Review
# 15  429419                   Implementation 2nd Review
# ...

# %%
def 

tasks_rt = tasks.loc[tasks['Owned By'].str.contains('Rajiv')]
#tasks_rt = tasks['Summary'].apply(lambda x: 'Code Review' if x.split()[-2:] == ['Code', 'Review'])
tasks_rt = tasks_rt.groupby('Summary').count()


tasks_rt.head(30)
# Out:
#                                            Id  Owned By  Status  Estimate  \
# Summary
# Code                                        4         4       4         4
# Code Review                                19        19      19        19
# Data Dictionary                             2         2       2         2
# Data Dictionary Review                     20        20      20        20
# Implementation Review                       2         2       2         2
# Improvement opportunities analysis (RA)     2         2       2         2
# Improvement opportunities analysis (RT)     1         1       1         1
# Optimization investigation and analysis 4   1         1       1         1
# Requirement Review                         17        17      17        17
# Sponsor Verification                        1         1       1         1
# UTCP                                        2         2       2         2
# ...
